# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mdates
from pyod.models.abod import ABOD
from pyod.models.knn import KNN

from sklearn.linear_model import LinearRegression
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split

# %%
def replace_with_neighbor_mean(data, index, column):
    for i in range(len(index)) : 
        left_val = data.loc[index[i]-1][column]
        right_val = data.loc[index[i]+1][column]
        replace_val = 0
        if (left_val > 0) and (right_val > 0):
            replace_val = (left_val + right_val) / 2
        elif(left_val > 0):
            replace_val = left_val
        elif(right_val > 0):
            replace_val = right_val
        data.loc[index[i], column] = replace_val
    index = []

# %%
Data_WL = pd.read_pickle('F:\Learning\Bsc.IT(Hon)\Research Project\ShortTerm Model\Data\Maspotha_WL_Filtered_Hourly.pkl')

# %%
Data_RF = pd.read_pickle('F:\Learning\Bsc.IT(Hon)\Research Project\ShortTerm Model\Data\Lyceum_Filtered_Hourly.pkl')

# %%
Data_WL.head(5)
# Out:
#                      water_height
# date_time
# 2019-02-23 00:00:00      0.293333
# 2019-02-23 01:00:00      0.291667
# 2019-02-23 02:00:00      0.288333
# 2019-02-23 03:00:00      0.290000
# 2019-02-23 04:00:00      0.291667

# %%
Data_RF.head(5)
# Out:
#                      air-rainfall
# DateTime
# 2018-03-29 12:00:00           0.0
# 2018-03-29 13:00:00           0.0
# 2018-03-29 14:00:00           0.0
# 2018-03-29 15:00:00           0.0
# 2018-03-29 16:00:00           0.0

# %% [markdown]
# ## Changing Column names

# %%
Data_WL.rename(columns={'date_time':'DateTime',
                     'water_height':'water-height'
                    }, 
                 inplace=True)

# %%
Data_WL.head(5)
# Out:
#                      water-height
# date_time
# 2019-02-23 00:00:00      0.293333
# 2019-02-23 01:00:00      0.291667
# 2019-02-23 02:00:00      0.288333
# 2019-02-23 03:00:00      0.290000
# 2019-02-23 04:00:00      0.291667

# %%
Data_RF.head(5)
# Out:
#                      air-rainfall
# DateTime
# 2018-03-29 12:00:00           0.0
# 2018-03-29 13:00:00           0.0
# 2018-03-29 14:00:00           0.0
# 2018-03-29 15:00:00           0.0
# 2018-03-29 16:00:00           0.0

# %% [markdown]
# ## Merging 2 Data Frames

# %%
start = max(Data_WL.index.min(), Data_RF.index.min())
end = min(Data_WL.index.max(), Data_RF.index.max())

df_time = pd.DataFrame({'time': pd.date_range(start,end,freq='H')})

df_A = Data_RF.reset_index()
df_B = Data_WL.reset_index()
df_C = df_B.copy()

df_A.columns = ['time', 'rain-fall']
df_B.columns = ['time', 'water-level']
# df_C.columns = ['time', 'pre-water-level']

# %% [raw]
#  for i, row in df_C.iterrows():
#     preWL = row['water-level']
# #       ifor_val = something
#       if i<10:
#         print(row['water-level'] )
# #         ifor_val = something_else
# #       df.at[i,'ifor'] = ifor_val

# %% [raw]
# df_C.at[0,'pre-water-level'] = df_C.loc[1,'pre-water-level']

# %% [raw]
#  for i, row in df_C.iterrows():
#       if i>1:
#         df_C.at[i-1,'pre-water-level'] = row['pre-water-level']

# %%
df_B.head(5)
# Out:
#                  time  water-level
# 0 2019-02-23 00:00:00     0.293333
# 1 2019-02-23 01:00:00     0.291667
# 2 2019-02-23 02:00:00     0.288333
# 3 2019-02-23 03:00:00     0.290000
# 4 2019-02-23 04:00:00     0.291667

# %% [raw]
# df_C.head(5)

# %% [raw]
# pd.merge_asof(pd.merge_asof(pd.merge_asof(df_time, df_A, on='time'), df_B, on='time') df_C, on='time')

# %%
df = pd.merge(df_A, df_B, on='time', how='inner')
# df = pd.merge(df, df_C, on='time', how='inner')

# %%
df.shape
# Out:
# (5329, 3)

# %%
df.head()
# Out:
#                  time  rain-fall  water-level
# 0 2019-02-23 00:00:00        0.0     0.293333
# 1 2019-02-23 01:00:00        0.0     0.291667
# 2 2019-02-23 02:00:00        0.0     0.288333
# 3 2019-02-23 03:00:00        0.0     0.290000
# 4 2019-02-23 04:00:00        0.0     0.291667

# %%
df_B.tail()
# Out:
#                     time  water-level
# 5324 2019-10-02 20:00:00     1.066667
# 5325 2019-10-02 21:00:00     1.021667
# 5326 2019-10-02 22:00:00     0.986667
# 5327 2019-10-02 23:00:00     0.956000
# 5328 2019-10-03 00:00:00     0.930000

# %% [raw]
# df.isnull().sum()

# %% [raw]
# df = df.dropna()

# %% [raw]
# df.isnull().sum()

# %% [markdown]
# ### Merging 6 hour lag

# %%
df_C = df_B.copy()
df_C.time = pd.to_datetime(df_C.time)

# %%
df_B.head(5)
# Out:
#                  time  water-level
# 0 2019-02-23 00:00:00     0.293333
# 1 2019-02-23 01:00:00     0.291667
# 2 2019-02-23 02:00:00     0.288333
# 3 2019-02-23 03:00:00     0.290000
# 4 2019-02-23 04:00:00     0.291667

# %%
df_C.time = df_C.time - pd.DateOffset(hours=6)

# %%
df_C.head(5)
# Out:
#                  time  water-level
# 0 2019-02-22 18:00:00     0.293333
# 1 2019-02-22 19:00:00     0.291667
# 2 2019-02-22 20:00:00     0.288333
# 3 2019-02-22 21:00:00     0.290000
# 4 2019-02-22 22:00:00     0.291667

# %%
df_C.columns = ['time', 'next-water-level']

# %%
df = pd.merge(df, df_C, on='time', how='inner')

# %%
df.shape
# Out:
# (5323, 4)

# %%
df.head(50)
# Out:
#                   time  rain-fall  water-level  next-water-level
# 0  2019-02-23 00:00:00        0.0     0.293333               NaN
# 1  2019-02-23 01:00:00        0.0     0.291667               NaN
# 2  2019-02-23 02:00:00        0.0     0.288333               NaN
# 3  2019-02-23 03:00:00        0.0     0.290000               NaN
# 4  2019-02-23 04:00:00        0.0     0.291667               NaN
# 5  2019-02-23 05:00:00        0.0     0.290000               NaN
# 6  2019-02-23 06:00:00        0.0          NaN               NaN
# 7  2019-02-23 07:00:00        0.0          NaN               NaN
# 8  2019-02-23 08:00:00        0.0          NaN               NaN
# 9  2019-02-23 09:00:00        0.0          NaN               NaN
# 10 2019-02-23 10:00:00        0.0          NaN               NaN
# 11 2019-02-23 11:00:00        0.0          NaN               NaN
# 12 2019-02-23 12:00:00        0.0          NaN               NaN
# 13 2019-02-23 13:00:00        0.0          NaN          0.290000
# 14 2019-02-23 14:00:00        0.0          NaN          0.283333
# 15 2019-02-23 15:00:00        0.0          NaN          0.286667
# 16 2019-02-23 16:00:00        0.0          NaN          0.291667
# 17 2019-02-23 17:00:00        0.0          NaN          0.286667
# 18 2019-02-23 18:00:00        0.0          NaN          0.290000
# 19 2019-02-23 19:00:00        0.0     0.290000          0.288333
# 20 2019-02-23 20:00:00        0.0     0.283333          0.281667
# 21 2019-02-23 21:00:00        0.0     0.286667          0.280000
# 22 2019-02-23 22:00:00        0.0     0.291667          0.278333
# 23 2019-02-23 23:00:00        0.0     0.286667          0.276667
# 24 2019-02-24 00:00:00        0.0     0.290000               NaN
# 25 2019-02-24 01:00:00        0.0     0.288333               NaN
# 26 2019-02-24 02:00:00        0.0     0.281667               NaN
# 27 2019-02-24 03:00:00        0.0     0.280000               NaN
# 28 2019-02-24 04:00:00        0.0     0.278333               NaN
# 29 2019-02-24 05:00:00        0.0     0.276667               NaN
# 30 2019-02-24 06:00:00        0.0          NaN               NaN
# 31 2019-02-24 07:00:00        0.0          NaN               NaN
# 32 2019-02-24 08:00:00        0.0          NaN               NaN
# 33 2019-02-24 09:00:00        0.0          NaN               NaN
# 34 2019-02-24 10:00:00        0.0          NaN               NaN
# 35 2019-02-24 11:00:00        0.0          NaN               NaN
# 36 2019-02-24 12:00:00        0.0          NaN               NaN
# 37 2019-02-24 13:00:00        0.0          NaN          0.280000
# 38 2019-02-24 14:00:00        0.0          NaN          0.280000
# 39 2019-02-24 15:00:00        0.0          NaN          0.283333
# 40 2019-02-24 16:00:00        0.0          NaN          0.286667
# 41 2019-02-24 17:00:00        0.0          NaN          0.280000
# 42 2019-02-24 18:00:00        0.0          NaN          0.281667
# 43 2019-02-24 19:00:00        0.0     0.280000          0.278333
# 44 2019-02-24 20:00:00        0.0     0.280000          0.278333
# 45 2019-02-24 21:00:00        0.0     0.283333          0.273333
# 46 2019-02-24 22:00:00        0.0     0.286667          0.270000
# 47 2019-02-24 23:00:00        0.0     0.280000          0.271667
# 48 2019-02-25 00:00:00        0.0     0.281667               NaN
# 49 2019-02-25 01:00:00        0.0     0.278333               NaN

# %%
df.tail(50)
# Out:
#                     time  rain-fall  water-level  next-water-level
# 5273 2019-09-30 17:00:00        0.0          NaN          0.330000
# 5274 2019-09-30 18:00:00        0.0          NaN          0.330000
# 5275 2019-09-30 19:00:00        0.0     0.331667          0.330000
# 5276 2019-09-30 20:00:00        0.0     0.328333          0.330000
# 5277 2019-09-30 21:00:00        0.0     0.338333          0.326667
# 5278 2019-09-30 22:00:00        0.0     0.331667          0.321667
# 5279 2019-09-30 23:00:00        0.0     0.330000          0.320000
# 5280 2019-10-01 00:00:00        0.0     0.330000               NaN
# 5281 2019-10-01 01:00:00        0.0     0.330000               NaN
# 5282 2019-10-01 02:00:00        0.0     0.330000               NaN
# 5283 2019-10-01 03:00:00        0.0     0.326667               NaN
# 5284 2019-10-01 04:00:00        0.0     0.321667               NaN
# 5285 2019-10-01 05:00:00        0.0     0.320000               NaN
# 5286 2019-10-01 06:00:00        0.0          NaN               NaN
# 5287 2019-10-01 07:00:00        0.0          NaN               NaN
# 5288 2019-10-01 08:00:00        0.0          NaN               NaN
# 5289 2019-10-01 09:00:00        0.0          NaN               NaN
# 5290 2019-10-01 10:00:00        0.0          NaN               NaN
# 5291 2019-10-01 11:00:00        0.0          NaN               NaN
# 5292 2019-10-01 12:00:00        0.0          NaN               NaN
# 5293 2019-10-01 13:00:00        0.0          NaN          0.320000
# 5294 2019-10-01 14:00:00        0.4          NaN          0.320000
# 5295 2019-10-01 15:00:00        0.0          NaN          0.321667
# 5296 2019-10-01 16:00:00        0.0          NaN          0.318333
# 5297 2019-10-01 17:00:00        0.0          NaN          0.318333
# 5298 2019-10-01 18:00:00       35.0          NaN          0.326667
# 5299 2019-10-01 19:00:00        4.0     0.320000          0.448000
# 5300 2019-10-01 20:00:00        0.0     0.320000          0.536667
# 5301 2019-10-01 21:00:00        0.2     0.321667          0.551667
# 5302 2019-10-01 22:00:00        0.0     0.318333          0.556667
# 5303 2019-10-01 23:00:00        0.0     0.318333          0.556667
# 5304 2019-10-02 00:00:00        0.0     0.326667               NaN
# 5305 2019-10-02 01:00:00        0.0     0.448000               NaN
# 5306 2019-10-02 02:00:00        0.0     0.536667               NaN
# 5307 2019-10-02 03:00:00        0.0     0.551667               NaN
# 5308 2019-10-02 04:00:00        0.0     0.556667               NaN
# 5309 2019-10-02 05:00:00        0.0     0.556667               NaN
# 5310 2019-10-02 06:00:00        0.0          NaN               NaN
# 5311 2019-10-02 07:00:00        0.0          NaN               NaN
# 5312 2019-10-02 08:00:00        0.0          NaN               NaN
# 5313 2019-10-02 09:00:00        0.0          NaN               NaN
# 5314 2019-10-02 10:00:00        0.0          NaN               NaN
# 5315 2019-10-02 11:00:00        0.0          NaN               NaN
# 5316 2019-10-02 12:00:00        0.0          NaN               NaN
# 5317 2019-10-02 13:00:00        0.0          NaN          1.116667
# 5318 2019-10-02 14:00:00        0.0          NaN          1.066667
# 5319 2019-10-02 15:00:00        0.0          NaN          1.021667
# 5320 2019-10-02 16:00:00        0.0          NaN          0.986667
# 5321 2019-10-02 17:00:00        0.0          NaN          0.956000
# 5322 2019-10-02 18:00:00        0.0          NaN          0.930000

# %%
df = df.dropna()

# %%
df.head(50)
# Out:
#                    time  rain-fall  water-level  next-water-level
# 19  2019-02-23 19:00:00        0.0     0.290000          0.288333
# 20  2019-02-23 20:00:00        0.0     0.283333          0.281667
# 21  2019-02-23 21:00:00        0.0     0.286667          0.280000
# 22  2019-02-23 22:00:00        0.0     0.291667          0.278333
# 23  2019-02-23 23:00:00        0.0     0.286667          0.276667
# 43  2019-02-24 19:00:00        0.0     0.280000          0.278333
# 44  2019-02-24 20:00:00        0.0     0.280000          0.278333
# 45  2019-02-24 21:00:00        0.0     0.283333          0.273333
# 46  2019-02-24 22:00:00        0.0     0.286667          0.270000
# 47  2019-02-24 23:00:00        0.0     0.280000          0.271667
# 67  2019-02-25 19:00:00        0.0     0.266667          0.271667
# 68  2019-02-25 20:00:00        0.0     0.270000          0.268333
# 69  2019-02-25 21:00:00        0.0     0.266667          0.270000
# 70  2019-02-25 22:00:00        0.0     0.270000          0.271667
# 71  2019-02-25 23:00:00        0.0     0.266667          0.270000
# 91  2019-02-26 19:00:00        0.0     0.256667          0.263333
# 92  2019-02-26 20:00:00        0.0     0.261667          0.263333
# 93  2019-02-26 21:00:00        0.0     0.263333          0.260000
# 94  2019-02-26 22:00:00        0.0     0.258333          0.260000
# 95  2019-02-26 23:00:00        0.0     0.260000          0.261667
# 115 2019-02-27 19:00:00        0.0     0.258333          0.258333
# 116 2019-02-27 20:00:00        0.0     0.263333          0.255000
# 117 2019-02-27 21:00:00        0.0     0.261667          0.265000
# 118 2019-02-27 22:00:00        0.0     0.263333          0.270000
# 119 2019-02-27 23:00:00        0.0     0.261667          0.280000
# 139 2019-02-28 19:00:00        0.0     0.275000          0.260000
# 140 2019-02-28 20:00:00        0.0     0.271667          0.261667
# 141 2019-02-28 21:00:00        0.0     0.270000          0.250000
# 142 2019-02-28 22:00:00        0.0     0.268333          0.255000
# 143 2019-02-28 23:00:00        0.0     0.263333          0.250000
# 163 2019-03-01 19:00:00        0.0     0.262500          0.250000
# 164 2019-03-01 20:00:00        0.0     0.260000          0.256667
# 165 2019-03-01 21:00:00        0.0     0.253333          0.261667
# 166 2019-03-01 22:00:00        0.0     0.259167          0.258333
# 167 2019-03-01 23:00:00        0.0     0.260000          0.256667
# 187 2019-03-02 19:00:00        0.0     0.273333          0.268333
# 188 2019-03-02 20:00:00        0.0     0.271667          0.261667
# 189 2019-03-02 21:00:00        0.0     0.268333          0.263333
# 190 2019-03-02 22:00:00        0.0     0.270000          0.263333
# 191 2019-03-02 23:00:00        0.0     0.273333          0.266667
# 211 2019-03-03 19:00:00        0.0     0.260000          0.256667
# 212 2019-03-03 20:00:00        0.0     0.263333          0.255000
# 213 2019-03-03 21:00:00        0.0     0.263333          0.253333
# 214 2019-03-03 22:00:00        0.0     0.261667          0.246667
# 215 2019-03-03 23:00:00        0.0     0.263333          0.248333
# 235 2019-03-04 19:00:00        0.0     0.226667          0.241667
# 236 2019-03-04 20:00:00        0.0     0.228333          0.241667
# 237 2019-03-04 21:00:00        0.0     0.231667          0.235000
# 238 2019-03-04 22:00:00        0.0     0.235000          0.241667
# 239 2019-03-04 23:00:00        0.0     0.233333          0.243333

# %% [markdown]
# ## Outliers

# %% [raw]
# outlier_index = df.index[df['rain-fall']>1]
# outlier_index.shape

# %% [raw]
# replace_with_neighbor_mean(df, outlier_index, 'rain-fall')

# %% [raw]
# df.loc[outlier_index]

# %% [raw]
# # Use seaborn style defaults and set the default figure size
# sns.set(rc={'figure.figsize':(17, 4)})
# df[1080:1100]['rain-fall'].plot(linewidth=0.5);

# %% [markdown]
# ## Changing Index

# %%
df = df.set_index('time')
df.index = pd.to_datetime(df.index)

# %%
# Use seaborn style defaults and set the default figure size
sns.set(rc={'figure.figsize':(17, 4)})
df['2019-03-01':'2019-10-01']['rain-fall'].plot(linewidth=0.5);

# %%
sns.set(rc={'figure.figsize':(17, 4)})
# Start and end of the date range to extract
start, end = '2019-03-01', '2019-03-01'
# Plot daily and weekly resampled time series together
fig, ax = plt.subplots()
ax.plot(df.loc[start:end, 'rain-fall'],
marker='.', linestyle='-', linewidth=0.5, label='rain-fall')
ax.plot(df.loc[start:end, 'water-level'],
marker='.', markersize=8, linestyle='-', label='water-level')
ax.set_ylabel('Water Height')
ax.legend();

# %%
df_filtered = df.between_time('19:00','05:00')

# %%
# Start and end of the date range to extract
start, end = '2019-03-01', '2019-03-01'
# Plot daily and weekly resampled time series together
fig, ax = plt.subplots()
ax.plot(df_filtered.loc[start:end, 'rain-fall'],
marker='.', linestyle='-', linewidth=0.5, label='rain-fall')
ax.plot(df_filtered.loc[start:end, 'water-level'],
marker='.', markersize=8, linestyle='-', label='water-level')
ax.set_ylabel('Water Height')
ax.legend();

# %%
sns.set(rc={'figure.figsize':(17, 100)})
# Start and end of the date range to extract
start, end = '2019-03-01', '2019-10-01'
# Plot daily and weekly resampled time series together
fig, ax = plt.subplots()
ax.plot(df_filtered.loc[start:end, 'rain-fall'],
marker='.', linestyle='-', linewidth=0.5, label='rain-fall')
ax.plot(df_filtered.loc[start:end, 'water-level'],
marker='.', markersize=8, linestyle='-', label='water-level')
ax.plot(df_filtered.loc[start:end, 'next-water-level'],
marker='', markersize=8, linestyle='-', label='next-water-level')
ax.set_ylabel('Water Height')
ax.legend();

# %%
# Use seaborn style defaults and set the default figure size
sns.set(rc={'figure.figsize':(17, 4)})
df_filtered[:]['water-level'].plot(linewidth=0.5);

# %% [markdown]
# ## Outliers

# %% [raw]
# negative_index = df_filtered.index[df_filtered['rain-fall']>1]

# %% [raw]
# df_filtered = df_filtered.drop(negative_index)

# %% [markdown]
# ## Normalizing Rain Fall

# %%
temp_df = df_filtered.copy()
temp_df['rain-fall'] = ((df_filtered['rain-fall']-df_filtered['rain-fall'].min())/(df_filtered['rain-fall'].max()-df_filtered['rain-fall'].min()))*5

# %%
temp_df.sample(5)
# Out:
#                      rain-fall  water-level  next-water-level
# time
# 2019-08-08 19:00:00        0.0     0.365000          0.338333
# 2019-03-21 22:00:00        0.0     0.213333          0.200000
# 2019-03-16 19:00:00        0.0     0.231667          0.236667
# 2019-09-26 20:00:00        0.0     0.468333          0.446667
# 2019-06-30 21:00:00        0.0     0.230000          0.220000

# %%
sns.set(rc={'figure.figsize':(50, 50)})
# Start and end of the date range to extract
start, end = '2019-03-01', '2019-10-01'
# Plot daily and weekly resampled time series together
fig, ax = plt.subplots()
ax.plot(temp_df.loc[start:end, 'rain-fall'],
marker='.', linestyle='-', linewidth=0.5, label='rain-fall')
ax.plot(temp_df.loc[start:end, 'water-level'],
marker='.', markersize=8, linestyle='-', label='water-level')
ax.plot(temp_df.loc[start:end, 'next-water-level'],
marker='.', markersize=8, linestyle='-', label='next-water-level')
ax.set_ylabel('Water Height')
ax.legend();

# %%
temp_df.tail(5)
# Out:
#                      rain-fall  water-level  next-water-level
# time
# 2019-10-01 19:00:00   0.636943     0.320000          0.448000
# 2019-10-01 20:00:00   0.000000     0.320000          0.536667
# 2019-10-01 21:00:00   0.031847     0.321667          0.551667
# 2019-10-01 22:00:00   0.000000     0.318333          0.556667
# 2019-10-01 23:00:00   0.000000     0.318333          0.556667

# %%
temp_df.shape
# Out:
# (1010, 3)

# %% [markdown]
# ## Linear Regression Model

# %%
# Build linear regression model using TV and Radio as predictors
# Split data into predictors X and output Y
predictors = ['rain-fall', 'water-level']
X = temp_df[predictors]
y = temp_df['next-water-level']

# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
X_train = X[:'2019-09-01']
X_test = X['2019-09-01':]
y_train = y[:'2019-09-01']
y_test = y['2019-09-01':]

# %%
y_test.head()
# Out:
# time
# 2019-09-03 23:00:00    0.311667
# 2019-09-04 19:00:00    0.300000
# 2019-09-04 20:00:00    0.300000
# 2019-09-04 21:00:00    0.300000
# 2019-09-04 22:00:00    0.296667
# Name: next-water-level, dtype: float64

# %%
# Initialise and fit model
lm = LinearRegression()
model = lm.fit(X_train, y_train)

# %%
print(f'alpha = {model.intercept_}')
print(f'betas = {model.coef_}')
# Out:
# alpha = 0.036892175710221214
# betas = [-0.00396668  0.87520208]

# %%
model.predict(X[:10])
# Out:
# array([0.29070078, 0.2848661 , 0.28778344, 0.29215945, 0.28778344,
#        0.28194876, 0.28194876, 0.2848661 , 0.28778344, 0.28194876])

# %%
predictions = lm.predict(X_test)

# %%
predictions[0:5]
# Out:
# array([0.30820482, 0.30091147, 0.30237014, 0.30091147, 0.2994528 ])

# %% [markdown]
# ## Testing results

# %% [raw]
# predictions.type

# %%
y_test = y_test.reset_index()

y_test.columns = ['time', 'Observed']
# df_C.columns = ['time', 'pre-water-level']

# %%
y_test = y_test.set_index('time')
y_test.index = pd.to_datetime(y_test.index)

# %%
y_test['Predicted'] = predictions

# %%
y_test['2019-10']['Predicted']
# Out:
# time
# 2019-10-01 19:00:00    0.314430
# 2019-10-01 20:00:00    0.316957
# 2019-10-01 21:00:00    0.318289
# 2019-10-01 22:00:00    0.315498
# 2019-10-01 23:00:00    0.315498
# Name: Predicted, dtype: float64

# %%
y_test.head()
# Out:
#                      Observed  Predicted
# time
# 2019-09-03 23:00:00  0.311667   0.308205
# 2019-09-04 19:00:00  0.300000   0.300911
# 2019-09-04 20:00:00  0.300000   0.302370
# 2019-09-04 21:00:00  0.300000   0.300911
# 2019-09-04 22:00:00  0.296667   0.299453

# %%
sns.set(rc={'figure.figsize':(100, 10)})
# Start and end of the date range to extract
# start, end = '2019-03-01', '2019-10-01'
# Plot daily and weekly resampled time series together
fig, ax = plt.subplots()
ax.plot(y_test.loc[:, 'Predicted'],
marker='.', linestyle='-', linewidth=0.5, label='Predicted')
ax.plot(y_test.loc[:, 'Observed'],
marker='.', markersize=8, linestyle='-', label='Observed')
ax.plot(X_test.loc[:, 'rain-fall'],
marker='.', markersize=8, linestyle='-', label='Rainfall')
ax.plot(X_test.loc[:, 'water-level'],
marker='.', markersize=8, linestyle='-', label='past data')
ax.set_ylabel('Water Height')
ax.legend();

# %% [raw]
# ## The line / model
# plt.scatter(y_test, predictions)
# plt.xlabel("True Values")
# plt.ylabel("Predictions")

# %%
predictions.shape
# Out:
# (129,)
